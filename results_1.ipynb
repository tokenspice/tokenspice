# %%
import pandas as pd
# Out:
# /home/shawn/.virtualenvs/TEC/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df = pd.read_csv('results/data.csv')

# %%
df
# Out:
#      Tick      Second     Min   Hour   Day      Month      Year   Num_mkts  \
# 0       0         0.0       0      0     0   0.000000  0.000000    1.00000
# 1      24     86400.0    1440     24     1   0.033333  0.002740    1.00052
# 2      48    172800.0    2880     48     2   0.066667  0.005479    1.00108
# 3      72    259200.0    4320     72     3   0.100000  0.008219    1.00163
# 4      96    345600.0    5760     96     4   0.133333  0.010959    1.00219
# ..    ...         ...     ...    ...   ...        ...       ...        ...
# 361  8664  31190400.0  519840   8664   361  12.033300  0.989041    1.22223
# 362  8688  31276800.0  521280   8688   362  12.066700  0.991781    1.22291
# 363  8712  31363200.0  522720   8712   363  12.100000  0.994521    1.22359
# 364  8736  31449600.0  524160   8736   364  12.133300  0.997260    1.22427
# 365  8760  31536000.0  525600   8760   365  12.166700  1.000000    1.22495
#
#       onemkt_rev/mo   onemkt_rev/yr  ...   OCEAN_minted_USD/mo  \
# ...

# %%
df.columns
# Out:
# /home/shawn/.virtualenvs/TEC/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Index(['Tick', ' Second', ' Min', ' Hour', ' Day', ' Month', ' Year',
#        ' Num_mkts', ' onemkt_rev/mo', ' onemkt_rev/yr', ' allmkts_rev/mo',
#        ' allmkts_rev/yr', ' ocean_rev/mo', ' ocean_rev/yr',
#        ' ocean_rev_growth/mo', ' ocean_rev_growth/yr', ' ps30_valuation',
#        ' overall_valuation', ' fundamentals_valuation',
#        ' speculation_valuation', ' tot_OCEAN_supply', ' tot_OCEAN_minted',
#        ' tot_OCEAN_burned', ' OCEAN_minted/mo', ' OCEAN_burned/mo',
#        ' OCEAN_minted_USD/mo', ' OCEAN_burned_USD/mo', ' OCEAN_price',
# ...

# %%
df[' speculation_valuation']
# Out:
# 0      5000000.0
# 1      5001370.0
# 2      5002740.0
# 3      5004110.0
# 4      5005480.0
#          ...
# 361    5519800.0
# 362    5521310.0
# 363    5522820.0
# 364    5524340.0
# 365    5525850.0
# Name:  speculation_valuation, Length: 366, dtype: float64
